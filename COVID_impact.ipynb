# %% [markdown]
# # COVID impact on company sales

# %%
import folium
import pandas as pd

# %%
### import datasets
city_info = pd.read_excel(r'/Users/royliao/Desktop/no.xlsx', sheet_name = 0)
city_number = pd.read_excel(r'/Users/royliao/Desktop/no.xlsx', sheet_name = 1)
city_all = city_info.merge(city_number, left_on='city', right_on='City')
company_info = pd.read_excel(r'/Users/royliao/Desktop/Excel_Høgskulen_juni21_-21100544.xlsx', sheet_name=3)
company_with_city = company_info.merge(city_all, left_on='KOMNR2', right_on='Number')

# %%
### define latituude and longitude
center_lat = company_with_city.mean().lat
center_long = company_with_city.mean().lng

### map setup
map = folium.Map(location=[center_lat, center_long], zoom_start=4.5)

### add data into map
for state in company_with_city["city"].unique():
    state_census = company_with_city[company_with_city["city"]==state]
    folium.CircleMarker(
        location=[state_census.lat.values[0], state_census.lng.values[0]],
        radius = float(state_census["Q4"].values[0]),
        popup="COVID affect on sales : %s"%state_census["Q2"].values[0],
        tooltip = state_census.city.values[0],
        color="black",
        fill_color="blue"
    ).add_to(m)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
